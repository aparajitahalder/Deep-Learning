# %%
#from sys import argv
import os
import cv2
import matplotlib.pyplot as plt

foldername=input("DATASET NAME : ")
filename=input("TRAINING : ")
testname=input("TESTING : ")
username1=input("USERNAME 1 : ")
username2=input("USERNAME 2 : ")


newpath=os.path.join(foldername, filename, username1)
newpath1=os.path.join(foldername, filename, username1,username1)

newpath2=os.path.join(foldername, testname, username1)
newpath3=os.path.join(foldername, testname, username1,username1)

newpath4=os.path.join(foldername, filename, username2)
newpath5=os.path.join(foldername, filename, username2,username2)

newpath6=os.path.join(foldername, testname, username2)
newpath7=os.path.join(foldername, testname, username2,username2)



if not os.path.exists(newpath):
    os.makedirs(newpath)
if not os.path.exists(newpath2):
    os.makedirs(newpath2)
if not os.path.exists(newpath4):
    os.makedirs(newpath4)
if not os.path.exists(newpath6):
    os.makedirs(newpath6)
    
    
video=cv2.VideoCapture(0)
count=1
while True:
        ret,frame=video.read()
        cv2.imshow('live video',frame)
        if count<=100:
            frame_RGB=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
            
            haar_face_cascade=cv2.CascadeClassifier("C:\\Users\\hp\\Downloads\\face1.xml")
            faces=haar_face_cascade.detectMultiScale(frame_RGB,scaleFactor=1.06,minNeighbors=5);
            for(x,y,w,h) in faces:
                cv2.rectangle(frame_RGB,(x,y),(x+w,y+h),(0,255,0),2)
                roi_color=frame_RGB[y:y+h,x:x+w]
            
            
            cv2.imwrite(newpath1+str(count)+'.png',roi_color)
            count+=1
            #will save in current folder
        elif count<=130:
            frame_RGB=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
            
            
            haar_face_cascade=cv2.CascadeClassifier("C:\\Users\\hp\\Downloads\\face1.xml")
            faces=haar_face_cascade.detectMultiScale(frame_RGB,scaleFactor=1.06,minNeighbors=5);
            for(x,y,w,h) in faces:
                cv2.rectangle(frame_RGB,(x,y),(x+w,y+h),(0,255,0),2)
                roi_color=frame_RGB[y:y+h,x:x+w]
            
            
            cv2.imwrite(newpath3+str(count)+'.png',roi_color)
            count+=1
        elif count>130:
             break

video.release()
cv2.destroyAllWindows()
# Out:
# DATASET NAME : dataset3
# TRAINING : train
# TESTING : test
# USERNAME 1 : appu
# USERNAME 2 : neha

# %%
video=cv2.VideoCapture(0)
count=1
while True:
        ret,frame=video.read()
        cv2.imshow('live video',frame)
        if count<=100:
            frame_RGB=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
            
            
            haar_face_cascade=cv2.CascadeClassifier("C:\\Users\\hp\\Downloads\\face1.xml")
            # download ibpcascade_frontal_face......... from goeduhub gmail
            faces=haar_face_cascade.detectMultiScale(frame_RGB,scaleFactor=1.06,minNeighbors=5);
            for(x,y,w,h) in faces:
                cv2.rectangle(frame_RGB,(x,y),(x+w,y+h),(0,255,0),2)
                roi_color=frame_RGB[y:y+h,x:x+w]
            
            
            cv2.imwrite(newpath5+str(count)+'.png',roi_color)
            count+=1
            #will save in current folder
        elif count<=130:
            frame_RGB=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
            
            haar_face_cascade=cv2.CascadeClassifier("C:\\Users\\hp\\Downloads\\face1.xml")
            faces=haar_face_cascade.detectMultiScale(frame_RGB,scaleFactor=1.06,minNeighbors=5);
            for(x,y,w,h) in faces:
                cv2.rectangle(frame_RGB,(x,y),(x+w,y+h),(0,255,0),2)
                roi_color=frame_RGB[y:y+h,x:x+w]
            
            
            cv2.imwrite(newpath7+str(count)+'.png',roi_color)
            count+=1
        elif count>130:
             break

video.release()
cv2.destroyAllWindows()

# %%
import cv2
import PIL
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import GlobalAveragePooling2D
from keras.layers import Flatten
from keras.layers import Dense
# Out:
# Using TensorFlow backend.

# %%
classifier = Sequential()

classifier.add(Conv2D(32, (5,5), input_shape=(64,64,3), activation = 'relu'))
# 32 filters of 5*5
#If you pass both batch_size=32 and input_shape=(6, 8) to a layer, 
#it will then expect every batch of inputs to have the batch shape (32, 6, 8).

classifier.add(MaxPooling2D(pool_size=(2,2)))
classifier.add(Conv2D(64, (5,5), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size=(2,2)))

classifier.add(Flatten())
# add full connection
classifier.add(Dense(units=128, activation='relu'))
classifier.add(Dense(units=1,   activation='sigmoid'))
#compiling the ANN
classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0701 23:43:15.583674  9200 deprecation_wrapper.py:119] From D:\Anaconda\envs\opencv-env\lib\site-packages\keras\backend\tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0701 23:43:15.965225  9200 deprecation_wrapper.py:119] From D:\Anaconda\envs\opencv-env\lib\site-packages\keras\backend\tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0701 23:43:16.085872  9200 deprecation_wrapper.py:119] From D:\Anaconda\envs\opencv-env\lib\site-packages\keras\backend\tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0701 23:43:16.193196  9200 deprecation_wrapper.py:119] From D:\Anaconda\envs\opencv-env\lib\site-packages\keras\backend\tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(rescale = 1./255,
                                  shear_range = 0.2,
                                  zoom_range = 0.2,
                                  horizontal_flip = True)

# %%
training_path=os.path.join(foldername, filename)

test_datagen = ImageDataGenerator(rescale = 1./255)
train_set = train_datagen.flow_from_directory(training_path,
                                             target_size = (64,64),
                                             batch_size = 32,
                                             class_mode = 'binary')
# Out:
# Found 200 images belonging to 2 classes.

# %%
test_path=os.path.join(foldername, testname)

test_size = test_datagen.flow_from_directory(test_path,
                                            target_size = (64,64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 60 images belonging to 2 classes.

# %%
classifier.fit_generator(train_set,
                        steps_per_epoch = 200,
                        epochs = 1,
                        validation_data = test_size,
                        validation_steps = 60,
                        )
classifier.save('model_binary_complex.h5')
# Out:
# W0701 23:53:37.059601  9200 deprecation_wrapper.py:119] From D:\Anaconda\envs\opencv-env\lib\site-packages\keras\backend\tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
# Epoch 1/1
# 200/200 [==============================] - 62s 308ms/step - loss: 0.2353 - acc: 0.8944 - val_loss: 0.0607 - val_acc: 0.9667

# %%
from keras.models import load_model
classifier=load_model('model_binary_complex.h5')

# %%
import numpy as np
from keras.preprocessing import image
prediction=input("SINGLE PREDICTION : ")
prediction_path=os.path.join(foldername, prediction)
prediction_path2=os.path.join(foldername, prediction,'appu_or_neha.png')

if not os.path.exists(prediction_path):
    os.makedirs(prediction_path)
# Out:
# SINGLE PREDICTION : single_prediction

# %%
test_image = image.load_img(prediction_path+'\\'+'appu_or_neha_1.png',
                           target_size = (300,300))

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
plt.imshow(test_image)
plt.show()

# %%
test_image = image.load_img(prediction_path+'\\'+'appu_or_neha_1.png',
                            target_size = (64,64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = classifier.predict(test_image)
train_set.class_indices
if result[0][0] ==1:
    prediction = 'neha'
else:
    prediction = 'appu'
prediction
# Out:
# 'neha'
